# %% [markdown]
# # Fintech-oriented EDA
# Charts are generated reproducibly by `python scripts/run_eda.py` and saved under `reports/figures`.

# %%
import sys
sys.path.insert(0, '..')
from scripts.run_eda import main
main()

# %% [markdown]
# ## Reading the plots
# Review amount tails, hourly fraud rate, payment-type/category risk, and class imbalance. These descriptive patterns motivate behavioral rather than single-condition rules.
